# %% [markdown]
# # Homework Assignment #1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Section 1: Police Killings

# %%
killings = pd.read_csv('../ga-ds-jenny/police-killings.csv', index_col=[0])
killings.head()
# Out:
#                  name  age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# 2        Kenosha Police Department  Gunshot       No          54930
# 3     South Gate Police Department  Gunshot  Firearm          55909
# 4           Kent Police Department  Gunshot       No          49669

# %% [markdown]
# ### 1. Make the following changes to column names:
#
# - Rename "lawenforcementagency" to "agency"
# - Rename "raceethnicity" to "race"

# %%
killings.rename(columns={"lawenforcementagency":"agency","raceethnicity":"race"}, inplace=True)

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
killings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 467 entries, 0 to 466
# Data columns (total 14 columns):
# name                    467 non-null object
# age                     467 non-null int64
# gender                  467 non-null object
# raceethnicity           467 non-null object
# month                   467 non-null object
# day                     467 non-null int64
# year                    467 non-null int64
# streetaddress           463 non-null object
# city                    467 non-null object
# state                   467 non-null object
# lawenforcementagency    467 non-null object
# cause                   467 non-null object
# armed                   467 non-null object
# county_income           467 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 54.7+ KB

# %% [markdown]
# ### 3. Replace each null/missing value in the dataframe with the string "unknown"

# %%
killings.fillna('unknown', inplace=True)
killings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 467 entries, 0 to 466
# Data columns (total 14 columns):
# name                    467 non-null object
# age                     467 non-null int64
# gender                  467 non-null object
# raceethnicity           467 non-null object
# month                   467 non-null object
# day                     467 non-null int64
# year                    467 non-null int64
# streetaddress           467 non-null object
# city                    467 non-null object
# state                   467 non-null object
# lawenforcementagency    467 non-null object
# cause                   467 non-null object
# armed                   467 non-null object
# county_income           467 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 54.7+ KB

# %% [markdown]
# ### 4. How many killings were there in March and April?

# %%
MAkillings = (killings.month == 'March') | (killings.month == 'April')
MAkillings.sum()
# Out:
# 210

# %% [markdown]
# ### 5. How many male and how many female victims are there?

# %%
Number_male=(killings.gender == 'Male').sum()
Number_male
# Out:
# 445

# %%
Number_female=(killings.gender == 'Female').sum()
Number_female
"""Question: Why .count does not work here? .count shows the total number"""
# Out:
# 22

# %% [markdown]
# ### 6. How many killings were of unarmed people?

# %%
killings['Number_unarmed']=(killings.armed == 'No').sum()
Number_unarmed
# Out:
# 102

# %% [markdown]
# ### 7. What percentage of all killings were unarmed?

# %%
Percent= float(Number_unarmed)/killings.name.count()
Percent
# Out:
# 0.21841541755888652

# %% [markdown]
# ### 8. What are the 5 states with the most killings?

# %%
state =  killings.state
state.value_counts().head()
# Out:
# CA    74
# TX    46
# FL    29
# AZ    25
# OK    22
# Name: state, dtype: int64

# %% [markdown]
# ### 9. Show a value counts of deaths for each race

# %%
race = killings.race
race.value_counts()
# Out:
# White                     236
# Black                     135
# Hispanic/Latino            67
# Unknown                    15
# Asian/Pacific Islander     10
# Native American             4
# Name: race, dtype: int64

# %% [markdown]
# ### 10. Display a histogram of ages of all killings

# %%
plt.hist(killings.age)
# Out:
# (array([  58.,   98.,  114.,   76.,   51.,   36.,   21.,    7.,    4.,    2.]),
#  array([ 16. ,  23.1,  30.2,  37.3,  44.4,  51.5,  58.6,  65.7,  72.8,
#          79.9,  87. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 11. Show histogram of ages for each race

# %%
race_age=killings.groupby('race').age.count()
plt.hist(race_age)
# Out:
# (array([ 3.,  0.,  1.,  0.,  0.,  1.,  0.,  0.,  0.,  1.]),
#  array([   4. ,   27.2,   50.4,   73.6,   96.8,  120. ,  143.2,  166.4,
#          189.6,  212.8,  236. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 12. What is the average age of death by race?

# %%
avg_age=killings.groupby(race).age.mean()
avg_age
# Out:
# race
# Asian/Pacific Islander    40.800000
# Black                     34.044444
# Hispanic/Latino           31.716418
# Native American           27.750000
# Unknown                   43.533333
# White                     40.466102
# Name: age, dtype: float64

# %% [markdown]
# ### 13. Show a bar chart with counts of deaths every month

# %%
month_death=killings.groupby('month').name.count()
pos=np.arange(month_death.size)
plt.figure(figsize=(15,5))
plt.bar(left=pos, height=month, tick_lable=month.index, align="center")

"""cannot figure oout the height """
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-155-761c2b100879> in <module>()
#       2 pos=np.arange(month_death.size)
#       3 plt.figure(figsize=(15,5))
# ----> 4 plt.bar(left=pos,  height=month, tick_lable=month.index, align="center")
#       5
#       6 """ """
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    2077         if len(height) != nbars:
#    2078             raise ValueError("incompatible sizes: argument 'height' "
# -> 2079                               "must be length %d or scalar" % nbars)
#    2080         if len(width) != nbars:
#    2081             raise ValueError("incompatible sizes: argument 'width' "
#
# ValueError: incompatible sizes: argument 'height' must be length 6 or scalar

# %% [markdown]
# ## Section 2: College Majors

# %%
majors = pd.read_csv('../ga-ds-jenny/college-majors.csv', index_col=[0])
majors.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# 3                          64937        3619           0.042679   46000
# 4                          12722         894           0.049188   62000
#
#    P25th    P75th
# 0  34000  80000.0
# 1  36000  80000.0
# 2  40000  98000.0
# 3  30000  72000.0
# 4  38500  90000.0

# %% [markdown]
# ### 1. Delete the columns (employed_full_time_year_round, major_code)

# %%
majors.drop(labels='Major_code', axis=1, inplace=True)
majors.drop(labels='Employed_full_time_year_round', axis=1, inplace=True)
majors.head()
# Out:
#                                    Major                   Major_category  \
# 0                    GENERAL AGRICULTURE  Agriculture & Natural Resources
# 1  AGRICULTURE PRODUCTION AND MANAGEMENT  Agriculture & Natural Resources
# 2                 AGRICULTURAL ECONOMICS  Agriculture & Natural Resources
# 3                        ANIMAL SCIENCES  Agriculture & Natural Resources
# 4                           FOOD SCIENCE  Agriculture & Natural Resources
#
#     Total  Employed  Unemployed  Unemployment_rate  Median  P25th    P75th
# 0  128148     90245        2423           0.026147   50000  34000  80000.0
# 1   95326     76865        2266           0.028636   54000  36000  80000.0
# 2   33955     26321         821           0.030248   63000  40000  98000.0
# 3  103549     81177        3619           0.042679   46000  30000  72000.0
# 4   24280     17281         894           0.049188   62000  38500  90000.0

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
majors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 172
# Data columns (total 9 columns):
# Major                173 non-null object
# Major_category       173 non-null object
# Total                173 non-null int64
# Employed             173 non-null int64
# Unemployed           173 non-null int64
# Unemployment_rate    173 non-null float64
# Median               173 non-null int64
# P25th                173 non-null int64
# P75th                173 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 13.5+ KB

# %% [markdown]
# ### 3. What are the top 10 highest paying majors?

# %%
highest=majors.sort_values('Median', ascending=False).head(10)
highest
# Out:
#                                                  Major  \
# 59                               PETROLEUM ENGINEERING
# 154  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 57           NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 55                           METALLURGICAL ENGINEERING
# 58                                 NUCLEAR ENGINEERING
# 56                      MINING AND MINERAL ENGINEERING
# 97                    MATHEMATICS AND COMPUTER SCIENCE
# 48                              ELECTRICAL ENGINEERING
# 45                                CHEMICAL ENGINEERING
# 51              GEOLOGICAL AND GEOPHYSICAL ENGINEERING
#
#               Major_category   Total  Employed  Unemployed  Unemployment_rate  \
# 59               Engineering   19631     14002         617           0.042205
# 154                   Health  180084    124058        4414           0.034358
# 57               Engineering   16094     10690         449           0.040309
# 55               Engineering   12818      6939         326           0.044873
# 58               Engineering    9826      7320         527           0.067159
# 56               Engineering   10746      7416         366           0.047032
# 97   Computers & Mathematics    7184      5874         150           0.024900
# 48               Engineering  671647    489965       26064           0.050509
# 45               Engineering  188046    131697        6388           0.046261
# 51               Engineering    6264      4120           0           0.000000
#
#      Median  P25th     P75th
# 59   125000  75000  210000.0
# 154  106000  78000  125000.0
# 57    97000  60000  125000.0
# 55    96000  65000  123000.0
# 58    95000  65000  128000.0
# 56    92000  52000  124000.0
# 97    92000  53000  136000.0
# 48    88000  60000  116000.0
# 45    86000  60000  120000.0
# 51    85000  55000  125000.0

# %% [markdown]
# ### 4. Plot the data from the last question in a bar chart, include proper title, and labels

# %%
pos=np.arange(majors.Median.size)
plt.bar(left=pos, height=majors.Major_category, tick_lable=Major_category.index, align="center")
"""cannot get the heigh again..."""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-190-0bc43658a850> in <module>()
#       1 pos=np.arange(majors.Median.size)
# ----> 2 plt.bar(left=pos, height=majors.Major_category, tick_lable=Major_category.index, align="center")
#
# NameError: name 'Major_category' is not defined

# %% [markdown]
# ### 5. What is the average median salary for each major category?

# %%
majors.groupby('Major_category').Median.mean()
# Out:
# Major_category
# Agriculture & Natural Resources        55000.000000
# Arts                                   43525.000000
# Biology & Life Science                 50821.428571
# Business                               60615.384615
# Communications & Journalism            49500.000000
# Computers & Mathematics                66272.727273
# Education                              43831.250000
# Engineering                            77758.620690
# Health                                 56458.333333
# Humanities & Liberal Arts              46080.000000
# Industrial Arts & Consumer Services    52642.857143
# Interdisciplinary                      43000.000000
# Law & Public Policy                    52800.000000
# Physical Sciences                      62400.000000
# Psychology & Social Work               44555.555556
# Social Science                         53222.222222
# Name: Median, dtype: float64

# %% [markdown]
# ### 6. Visualize only the top 5 paying major categories

# %%
top5=majors.sort_values('Median', ascending=False).head()
top5
Median=majors.Median
pos=np.arange(Median.size)
plt.bar(left=pos, height=Major_category, tick_lable=Major_category.index, align="center")

"""Still cannot get the Height"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-206-be1c59e97b84> in <module>()
#       3 Median=majors.Median
#       4 pos=np.arange(Median.size)
# ----> 5 plt.bar(left=pos, height=Major_category, tick_lable=Major_category.index, align="center")
#       6
#       7 """Still cannot get the Height"""
#
# NameError: name 'Major_category' is not defined

# %% [markdown]
# ### 7. Plot a histogram of the distribution of median salaries

# %%
plt.hist(Median)
# Out:
# (array([ 25.,  61.,  32.,  31.,  10.,   7.,   5.,   1.,   0.,   1.]),
#  array([  35000.,   44000.,   53000.,   62000.,   71000.,   80000.,
#           89000.,   98000.,  107000.,  116000.,  125000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 8. Plot a histogram of the distribution of median salaries by major category

# %%
majorcategory_median=majors.groupby('Major_category').Median
plt.hist(majorcategory_median)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-212-60f8d88f04c3> in <module>()
#       1 majorcategory_median=majors.groupby('Major_category').Median
# ----> 2 plt.hist(majorcategory_median)
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3079                       histtype=histtype, align=align, orientation=orientation,
#    3080                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3081                       stacked=stacked, data=data, **kwargs)
#    3082     finally:
#    3083         ax._hold = washold
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(***failed resolving arguments***)
#    6136
#    6137         # basic input validation
# -> 6138         flat = np.ravel(x)
#    6139
#    6140         input_empty = len(flat) == 0
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in ravel(a, order)
#    1466         return asarray(a).ravel(order=order)
#    1467     else:
# -> 1468         return asanyarray(a).ravel(order=order)
#    1469
#    1470
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asanyarray(a, dtype, order)
#     581
#     582     """
# --> 583     return array(a, dtype, copy=False, order=order, subok=True)
#     584
#     585
#
# ValueError: cannot set an array element with a sequence

# %% [markdown]
# ### 9. What are the top 10 most UNemployed majors?

# %%
UNemployed=majors.sort_values('Unemployed', ascending=False).head(10)
UNemployed
# Out:
#                                       Major               Major_category  \
# 161  BUSINESS MANAGEMENT AND ADMINISTRATION                     Business
# 158                        GENERAL BUSINESS                     Business
# 114                              PSYCHOLOGY     Psychology & Social Work
# 159                              ACCOUNTING                     Business
# 13                           COMMUNICATIONS  Communications & Journalism
# 73          ENGLISH LANGUAGE AND LITERATURE    Humanities & Liberal Arts
# 164        MARKETING AND MARKETING RESEARCH                     Business
# 132        POLITICAL SCIENCE AND GOVERNMENT               Social Science
# 25                        GENERAL EDUCATION                    Education
# 78                                  BIOLOGY       Biology & Life Science
#
#        Total  Employed  Unemployed  Unemployment_rate  Median  P25th     P75th
# 161  3123510   2354398      147261           0.058865   58000  39500   86000.0
# 158  2148712   1580978       85626           0.051378   60000  40000   95000.0
# 114  1484075   1055854       79066           0.069667   45000  31000   68000.0
# 159  1779219   1335825       75379           0.053415   65000  42500  100000.0
# 13    987676    790696       54390           0.064360   50000  35000   80000.0
# 73   1098647    708882       52248           0.068645   50000  32900   75000.0
# 164  1114624    890125       51839           0.055033   56000  38500   90000.0
# 132   748956    541630       40376           0.069374   58000  38000   90000.0
# 25   1438867    843693       38742           0.043904   43000  32000   59000.0
# 78    839454    583079       36757           0.059301   51000  35000   80000.0

# %% [markdown]
# ### 10. What are the top 10 most UNemployed majors CATEGORIES? Use the mean for each category

# %%
Un_category=majors.groupby('Major_category').Unemployed.mean()
majors.sort_values('Un_category',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-222-475f9fd7e8eb> in <module>()
#       1 Un_category=majors.groupby('Major_category').Unemployed.mean()
# ----> 2 majors.sort_values('Un_category',ascending=False).head(10)
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3282
#    3283             by = by[0]
# -> 3284             k = self.xs(by, axis=other_axis).values
#    3285             if k.ndim == 2:
#    3286
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    1910
#    1911         if axis == 1:
# -> 1912             return self[key]
#    1913
#    1914         self._consolidate_inplace()
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Un_category'

# %% [markdown]
# ## Section 3: FIFA Soccer Game data

# %%
fifa = pd.read_csv('../ga-ds-jenny/fifa_data.csv')
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# 0     ...              90    81                76        85       88
# 1     ...              88    89                90        74       85
# 2     ...              77    79                84        81       83
# 3     ...              86    86                84        85       88
# 4     ...              16    14                11        47       11
#
#   GK_Positioning GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# 0             14         7          15           11           11
# 1             14         6          15           11            8
# 2             15         9          15            9           11
# 3             33        27          31           25           37
# 4             91        89          95           90           89
#
# [5 rows x 53 columns]

# %% [markdown]
# ### 1. Clean up the dataset.
#
#     - Lowercase the column names
#     - Set the "name" column as the index
#     - Drop the following columns "national_position", "national_kit", "club_kit", "club_joining", and "contract_expiry"
#     - Get rid of all players who are goalkeepers and drop every column that starts with GK
#     - Drop every player whose rating is less than 70
#     - Convert the "height" and "weight" columns to float types
#     - Check to see if there any nulls, if so drop them from the dataset

# %%
fifa.columns = map(str.lower, fifa.columns)

# %%
fifa.set_index('name', inplace=True)

# %%
fifa.drop(labels='national_position', axis=1, inplace=True)
fifa.drop(labels='national_kit', axis=1, inplace=True)
fifa.drop(labels='club_kit', axis=1, inplace=True)
fifa.drop(labels='club_joining', axis=1, inplace=True)
fifa.drop(labels='contract_expiry', axis=1, inplace=True)

# %%
GK=fifa.club_position == 'GK'
"""Don't know how to drop them"""
# Out:
# name
# Cristiano Ronaldo     True
# Lionel Messi          True
# Neymar                True
# Luis Suárez           True
# Manuel Neuer          True
# De Gea                True
# Robert Lewandowski    True
# Gareth Bale           True
# Zlatan Ibrahimović    True
# Thibaut Courtois      True
# Jérôme Boateng        True
# Eden Hazard           True
# Luka Modrić           True
# Mesut Özil            True
# Gonzalo Higuaín       True
# Thiago Silva          True
# Sergio Ramos          True
# Sergio Agüero         True
# Paul Pogba            True
# Antoine Griezmann     True
# Kevin De Bruyne       True
# Marco Reus            True
# Alexis Sánchez        True
# Toni Kroos            True
# Diego Godín           True
# Mats Hummels          True
# Hugo Lloris           True
# Giorgio Chiellini     True
# Philipp Lahm          True
# Pepe                  True
#                       ...
# Kieran Butler         True
# Kyle Egan             True
# Alfie Kilgour         True
# Shane Hanney          True
# Louis Jones           True
# Ben Kelly             True
# Kaylen Hinds          True
# James King            True
# Neil McLaughlin       True
# Nathan Clifford       True
# Ciaran Kelly          True
# Adam Kelsey           True
# Dominic Peppard       True
# Gavin Dowling         True
# Tommy Käßemodel       True
# Ronan Wilson          True
# Darragh Doherty       True
# Myles Judd            True
# Sam Hornby            True
# Sam Sargeant          True
# Steven Alzate         True
# Sam Dalby             True
# Henry Ochieng         True
# Harry Clifton         True
# Mark McElhinney       True
# Adam Dunbar           True
# Dylan McGoey          True
# Tommy Ouldridge       True
# Mark Foden            True
# Barry Richardson      True
# Name: club_position, Length: 17588, dtype: bool

# %%
fifa
# Out:
#                             nationality             club club_position  \
# name
# Cristiano Ronaldo              Portugal      Real Madrid            LW
# Lionel Messi                  Argentina     FC Barcelona            RW
# Neymar                           Brazil     FC Barcelona            LW
# Luis Suárez                     Uruguay     FC Barcelona            ST
# Manuel Neuer                    Germany        FC Bayern            GK
# De Gea                            Spain   Manchester Utd            GK
# Robert Lewandowski               Poland        FC Bayern            ST
# Gareth Bale                       Wales      Real Madrid            RW
# Zlatan Ibrahimović               Sweden   Manchester Utd            ST
# Thibaut Courtois                Belgium          Chelsea            GK
# Jérôme Boateng                  Germany        FC Bayern           Sub
# Eden Hazard                     Belgium          Chelsea            LW
# Luka Modrić                     Croatia      Real Madrid           RCM
# Mesut Özil                      Germany          Arsenal           CAM
# Gonzalo Higuaín               Argentina         Juventus            ST
# Thiago Silva                     Brazil              PSG           LCB
# Sergio Ramos                      Spain      Real Madrid           LCB
# Sergio Agüero                 Argentina  Manchester City            ST
# Paul Pogba                       France   Manchester Utd           LCM
# Antoine Griezmann                France  Atlético Madrid            RS
# Kevin De Bruyne                 Belgium  Manchester City           RCM
# Marco Reus                      Germany    Bor. Dortmund            LW
# Alexis Sánchez                    Chile          Arsenal            ST
# Toni Kroos                      Germany      Real Madrid           LCM
# Diego Godín                     Uruguay  Atlético Madrid           LCB
# Mats Hummels                    Germany        FC Bayern           LCB
# Hugo Lloris                      France            Spurs            GK
# Giorgio Chiellini                 Italy         Juventus           LCB
# Philipp Lahm                    Germany        FC Bayern            RB
# Pepe                           Portugal      Real Madrid           RCB
# ...                                 ...              ...           ...
# Kieran Butler       Republic of Ireland   Bray Wanderers           Res
# Kyle Egan                       England      Exeter City           Res
# Alfie Kilgour                   England   Bristol Rovers           Res
# Shane Hanney        Republic of Ireland  Shamrock Rovers           Sub
# Louis Jones                     England        Doncaster           Sub
# Ben Kelly           Republic of Ireland          Dundalk           Sub
# Kaylen Hinds                    England        Stevenage           Res
# James King                      England    Bradford City           Res
# Neil McLaughlin                Scotland  Partick Thistle           Sub
# Nathan Clifford     Republic of Ireland       Finn Harps           Res
# Ciaran Kelly        Republic of Ireland       Finn Harps           Sub
# Adam Kelsey                     England   Scunthorpe Utd           Res
# Dominic Peppard     Republic of Ireland      Bohemian FC           Sub
# Gavin Dowling       Republic of Ireland   Wexford Youths           Sub
# Tommy Käßemodel                 Germany   Erzgebirge Aue           Res
# Ronan Wilson           Northern Ireland       Derry City           Sub
# Darragh Doherty     Republic of Ireland    Longford Town           Sub
# Myles Judd                      England    Leyton Orient           Sub
# Sam Hornby                      England    Burton Albion           Res
# Sam Sargeant                    England    Leyton Orient           Sub
# Steven Alzate                   England    Leyton Orient           Res
# Sam Dalby                       England    Leyton Orient           Sub
# Henry Ochieng                   England    Leyton Orient           Sub
# Harry Clifton                   England     Grimsby Town           Res
# Mark McElhinney     Republic of Ireland       Derry City           Res
# Adam Dunbar         Republic of Ireland   Wexford Youths           Sub
# Dylan McGoey        Republic of Ireland    Longford Town           Sub
# Tommy Ouldridge                 England     Swindon Town           Res
# Mark Foden                     Scotland      Ross County           Sub
# Barry Richardson                England          Wycombe           Sub
#
#                     rating  height weight preffered_foot  birth_date  age  \
# name
# Cristiano Ronaldo       94  185 cm  80 kg          Right  02/05/1985   32
# Lionel Messi            93  170 cm  72 kg           Left  06/24/1987   29
# Neymar                  92  174 cm  68 kg          Right  02/05/1992   25
# Luis Suárez             92  182 cm  85 kg          Right  01/24/1987   30
# Manuel Neuer            92  193 cm  92 kg          Right  03/27/1986   31
# De Gea                  90  193 cm  82 kg          Right  11/07/1990   26
# Robert Lewandowski      90  185 cm  79 kg          Right  08/21/1988   28
# Gareth Bale             90  183 cm  74 kg           Left  07/16/1989   27
# Zlatan Ibrahimović      90  195 cm  95 kg          Right  10/03/1981   35
# Thibaut Courtois        89  199 cm  91 kg           Left  05/11/1992   24
# Jérôme Boateng          89  192 cm  90 kg          Right  09/03/1988   28
# Eden Hazard             89  173 cm  74 kg          Right  01/07/1991   26
# Luka Modrić             89  174 cm  65 kg          Right  09/09/1985   31
# Mesut Özil              89  180 cm  76 kg           Left  10/15/1988   28
# Gonzalo Higuaín         89  184 cm  92 kg          Right  12/10/1987   29
# Thiago Silva            89  183 cm  79 kg          Right  09/22/1984   32
# Sergio Ramos            89  183 cm  75 kg          Right  03/30/1986   31
# Sergio Agüero           89  173 cm  70 kg          Right  06/02/1988   28
# Paul Pogba              88  191 cm  84 kg          Right  03/15/1993   24
# Antoine Griezmann       88  176 cm  67 kg           Left  03/21/1991   26
# Kevin De Bruyne         88  181 cm  68 kg          Right  06/28/1991   25
# Marco Reus              88  182 cm  76 kg          Right  05/31/1989   27
# Alexis Sánchez          88  169 cm  62 kg          Right  12/19/1988   28
# Toni Kroos              88  182 cm  78 kg          Right  01/04/1990   27
# Diego Godín             88  185 cm  73 kg          Right  02/16/1986   31
# Mats Hummels            88  191 cm  92 kg          Right  12/16/1988   28
# Hugo Lloris             88  188 cm  82 kg           Left  12/26/1986   30
# Giorgio Chiellini       88  187 cm  84 kg           Left  08/14/1984   32
# Philipp Lahm            88  170 cm  66 kg          Right  11/11/1983   33
# Pepe                    88  188 cm  81 kg          Right  02/26/1983   34
# ...                    ...     ...    ...            ...         ...  ...
# Kieran Butler           47  185 cm  78 kg          Right  06/12/1999   17
# Kyle Egan               47  180 cm  75 kg          Right  02/15/1998   19
# Alfie Kilgour           47  178 cm  75 kg          Right  05/18/1998   18
# Shane Hanney            47  182 cm  74 kg          Right  02/19/1998   19
# Louis Jones             47  185 cm  74 kg          Right  10/12/1998   18
# Ben Kelly               47  183 cm  82 kg          Right  07/26/1997   19
# Kaylen Hinds            47  185 cm  68 kg          Right  01/21/1998   19
# James King              47  177 cm  73 kg          Right  12/27/1996   20
# Neil McLaughlin         47  177 cm  70 kg          Right  01/01/1998   19
# Nathan Clifford         46  175 cm  67 kg          Right  07/09/1997   19
# Ciaran Kelly            46  177 cm  64 kg          Right  10/25/1998   18
# Adam Kelsey             46  188 cm  74 kg          Right  11/12/1999   17
# Dominic Peppard         46  173 cm  68 kg          Right  02/17/2000   17
# Gavin Dowling           46  185 cm  80 kg          Right  12/15/1978   38
# Tommy Käßemodel         46  173 cm  75 kg          Right  08/09/1988   28
# Ronan Wilson            46  184 cm  75 kg          Right  09/01/1998   18
# Darragh Doherty         46  178 cm  75 kg          Right  07/03/1997   19
# Myles Judd              46  178 cm  67 kg          Right  02/24/1999   18
# Sam Hornby              46  188 cm  80 kg          Right  02/14/1995   22
# Sam Sargeant            46  183 cm  67 kg          Right  09/23/1997   19
# Steven Alzate           45  177 cm  65 kg          Right  09/08/1998   18
# Sam Dalby               45  191 cm  78 kg          Right  12/07/1999   17
# Henry Ochieng           45  179 cm  67 kg          Right  11/11/1998   18
# Harry Clifton           45  180 cm  88 kg          Right  06/12/1998   18
# Mark McElhinney         45  182 cm  76 kg          Right  03/04/1998   19
# Adam Dunbar             45  183 cm  82 kg          Right  01/04/1998   19
# Dylan McGoey            45  185 cm  80 kg          Right  11/08/1997   19
# Tommy Ouldridge         45  173 cm  61 kg          Right  11/26/1998   18
# Mark Foden              45  180 cm  80 kg          Right  03/19/1996   21
# Barry Richardson        45  185 cm  77 kg          Right  08/05/1969   47
#
#                    preffered_position     ...      long_shots  curve  \
# name                                      ...
# Cristiano Ronaldo               LW/ST     ...              90     81
# Lionel Messi                       RW     ...              88     89
# Neymar                             LW     ...              77     79
# Luis Suárez                        ST     ...              86     86
# Manuel Neuer                       GK     ...              16     14
# De Gea                             GK     ...              12     21
# Robert Lewandowski                 ST     ...              82     77
# Gareth Bale                        RW     ...              90     86
# Zlatan Ibrahimović                 ST     ...              88     82
# Thibaut Courtois                   GK     ...              17     19
# Jérôme Boateng                     CB     ...              58     56
# Eden Hazard                     LW/LM     ...              82     82
# Luka Modrić                    CM/CDM     ...              82     79
# Mesut Özil                     CAM/LW     ...              76     84
# Gonzalo Higuaín                    ST     ...              80     74
# Thiago Silva                       CB     ...              71     61
# Sergio Ramos                       CB     ...              55     73
# Sergio Agüero                      ST     ...              84     82
# Paul Pogba                     CM/CAM     ...              88     82
# Antoine Griezmann               ST/LW     ...              82     84
# Kevin De Bruyne             CAM/RM/LM     ...              86     81
# Marco Reus                     LM/CAM     ...              85     90
# Alexis Sánchez                  ST/RM     ...              81     78
# Toni Kroos                     CM/CDM     ...              88     85
# Diego Godín                        CB     ...              43     49
# Mats Hummels                       CB     ...              51     65
# Hugo Lloris                        GK     ...              14     11
# Giorgio Chiellini                  CB     ...              49     60
# Philipp Lahm                    RB/CM     ...              65     77
# Pepe                               CB     ...              56     44
# ...                               ...     ...             ...    ...
# Kieran Butler                      CB     ...              23     26
# Kyle Egan                          RB     ...              23     28
# Alfie Kilgour                      CB     ...              28     33
# Shane Hanney                       CM     ...              43     39
# Louis Jones                        GK     ...              14     12
# Ben Kelly                          GK     ...              12     18
# Kaylen Hinds                       CF     ...              47     37
# James King                         CB     ...              18     26
# Neil McLaughlin                ST/CAM     ...              30     34
# Nathan Clifford                 RB/LB     ...              22     33
# Ciaran Kelly                       CB     ...              17     29
# Adam Kelsey                        GK     ...               7     13
# Dominic Peppard                 RB/CM     ...              16     28
# Gavin Dowling                      GK     ...              11     13
# Tommy Käßemodel                    CM     ...              39     52
# Ronan Wilson                   CM/CAM     ...              33     23
# Darragh Doherty                 CM/RB     ...              32     32
# Myles Judd                         RB     ...              22     27
# Sam Hornby                         GK     ...              18     19
# Sam Sargeant                       GK     ...              13     16
# Steven Alzate                     CAM     ...              29     40
# Sam Dalby                          ST     ...              44     34
# Henry Ochieng                      CM     ...              36     32
# Harry Clifton                      CM     ...              35     32
# Mark McElhinney                    GK     ...              12     11
# Adam Dunbar                        GK     ...              13     11
# Dylan McGoey                       GK     ...              11     12
# Tommy Ouldridge                    CM     ...              42     35
# Mark Foden                         GK     ...              12     13
# Barry Richardson                   GK     ...              16     12
#
#                     freekick_accuracy  penalties  volleys  gk_positioning  \
# name
# Cristiano Ronaldo                  76         85       88              14
# Lionel Messi                       90         74       85              14
# Neymar                             84         81       83              15
# Luis Suárez                        84         85       88              33
# Manuel Neuer                       11         47       11              91
# De Gea                             19         40       13              86
# Robert Lewandowski                 76         81       86               8
# Gareth Bale                        85         76       76               5
# Zlatan Ibrahimović                 82         91       93               9
# Thibaut Courtois                   11         27       12              86
# Jérôme Boateng                     31         46       53               6
# Eden Hazard                        79         86       79               8
# Luka Modrić                        77         80       74              14
# Mesut Özil                         79         67       77               6
# Gonzalo Higuaín                    62         70       88               5
# Thiago Silva                       73         71       63               9
# Sergio Ramos                       67         68       66               7
# Sergio Agüero                      72         80       85              11
# Paul Pogba                         82         76       84               4
# Antoine Griezmann                  75         71       87              13
# Kevin De Bruyne                    84         77       82              10
# Marco Reus                         84         84       88              13
# Alexis Sánchez                     78         77       83              12
# Toni Kroos                         84         73       82               7
# Diego Godín                        51         50       47               5
# Mats Hummels                       53         68       60               5
# Hugo Lloris                        10         40       11              82
# Giorgio Chiellini                  31         50       45               4
# Philipp Lahm                       59         69       66              14
# Pepe                               47         57       23               9
# ...                               ...        ...      ...             ...
# Kieran Butler                      25         35       24              12
# Kyle Egan                          28         35       23               9
# Alfie Kilgour                      24         35       19              10
# Shane Hanney                       41         44       35              13
# Louis Jones                        13         48       15              45
# Ben Kelly                          17         13       15              46
# Kaylen Hinds                       26         62       36               9
# James King                         16         32       22              10
# Neil McLaughlin                    30         39       41              14
# Nathan Clifford                    28         20       19              13
# Ciaran Kelly                       25         28       17               7
# Adam Kelsey                        12         17        6              43
# Dominic Peppard                    20         31       28               5
# Gavin Dowling                      10         12       12              43
# Tommy Käßemodel                    37         41       34              13
# Ronan Wilson                       21         36       22              11
# Darragh Doherty                    33         40       26               9
# Myles Judd                         29         33       21              12
# Sam Hornby                         13         14       12              41
# Sam Sargeant                       13         24       16              47
# Steven Alzate                      22         35       30               7
# Sam Dalby                          23         40       35              12
# Henry Ochieng                      31         36       25               7
# Harry Clifton                      27         24       27               7
# Mark McElhinney                    11         16       12              46
# Adam Dunbar                        13         15       12              39
# Dylan McGoey                       13         16       12              47
# Tommy Ouldridge                    36         42       37              15
# Mark Foden                         12         24       12              40
# Barry Richardson                   11         22       12              58
#
#                     gk_diving  gk_kicking  gk_handling  gk_reflexes
# name
# Cristiano Ronaldo           7          15           11           11
# Lionel Messi                6          15           11            8
# Neymar                      9          15            9           11
# Luis Suárez                27          31           25           37
# Manuel Neuer               89          95           90           89
# De Gea                     88          87           85           90
# Robert Lewandowski         15          12            6           10
# Gareth Bale                15          11           15            6
# Zlatan Ibrahimović         13          10           15           12
# Thibaut Courtois           84          69           91           89
# Jérôme Boateng              7          15           12            5
# Eden Hazard                11           6           12            8
# Luka Modrić                13           7            9            9
# Mesut Özil                  6          10           14           14
# Gonzalo Higuaín             5           7           12           10
# Thiago Silva                9           5           12           10
# Sergio Ramos               11           9            8           11
# Sergio Agüero              13           6           15           14
# Paul Pogba                  5           2            6            3
# Antoine Griezmann          14          14            8           14
# Kevin De Bruyne            15           5           13           13
# Marco Reus                 12          13           12           11
# Alexis Sánchez             10          15           10           13
# Toni Kroos                 10          13           11           10
# Diego Godín                 6          15            8           15
# Mats Hummels               15          10            6            6
# Hugo Lloris                87          68           87           90
# Giorgio Chiellini           3           2            3            3
# Philipp Lahm               11           5           12            5
# Pepe                        8           5           15           10
# ...                       ...         ...          ...          ...
# Kieran Butler              12          12            8            6
# Kyle Egan                   7          10            8            8
# Alfie Kilgour               6          11           11            5
# Shane Hanney               14          12            5           14
# Louis Jones                45          43           43           48
# Ben Kelly                  48          50           46           44
# Kaylen Hinds               15          13           11            6
# James King                  6           7           15           12
# Neil McLaughlin             8          15           16            9
# Nathan Clifford            12           8           11            5
# Ciaran Kelly                7           9           14           15
# Adam Kelsey                46          54           47           48
# Dominic Peppard            13           5           15           13
# Gavin Dowling              45          57           44           46
# Tommy Käßemodel            10           6           12            6
# Ronan Wilson               11          11            8           10
# Darragh Doherty             7          14           10           10
# Myles Judd                  5          14            5           10
# Sam Hornby                 50          44           42           48
# Sam Sargeant               48          43           42           51
# Steven Alzate               9           6            6            6
# Sam Dalby                   7          14           12            7
# Henry Ochieng              12          12           13            9
# Harry Clifton               9           8            6           10
# Mark McElhinney            41          50           45           44
# Adam Dunbar                44          52           41           46
# Dylan McGoey               39          46           46           46
# Tommy Ouldridge             7          13           14            7
# Mark Foden                 45          44           43           45
# Barry Richardson           37          37           51           33
#
# [17588 rows x 47 columns]

# %%
fifa.drop(labels='gk_positioning', axis=1, inplace=True)
fifa.drop(labels='gk_diving', axis=1, inplace=True)
fifa.drop(labels='gk_kicking', axis=1, inplace=True)
fifa.drop(labels= 'gk_handling', axis=1, inplace=True)
fifa.drop(labels='gk_reflexes', axis=1, inplace=True)

# %%
fifa.drop(subset = fifa.rating<70, inplace=True)

"""don't know how to drop rows"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-268-396eacd12b4a> in <module>()
# ----> 1 fifa.drop(subset = fifa.rating<70, inplace=True)
#
# TypeError: drop() got an unexpected keyword argument 'subset'

# %%
fifa['height','weight']=fifa['height','weight'].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-269-1a4a2671a18a> in <module>()
# ----> 1 fifa['height','weight']=fifa['height','weight'].apply(pd.to_numeric)
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: ('height', 'weight')

# %% [markdown]
# ### 2.  Who are the top five players of the following attributes: speed, marking, and finishing

# %%
qualify=['speed','marking','finishing']
fifa[fifa.rating.isin(qualify)]

"don't know how to make sure the players have data in those three columns"
# Out:
# Empty DataFrame
# Columns: [nationality, club, club_position, rating, height, weight, preffered_foot, birth_date, age, preffered_position, work_rate, weak_foot, skill_moves, ball_control, dribbling, marking, sliding_tackle, standing_tackle, aggression, reactions, attacking_position, interceptions, vision, composure, crossing, short_pass, long_pass, acceleration, speed, stamina, strength, balance, agility, jumping, heading, shot_power, finishing, long_shots, curve, freekick_accuracy, penalties, volleys]
# Index: []
#
# [0 rows x 42 columns]

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17588 entries, Cristiano Ronaldo to Barry Richardson
# Data columns (total 42 columns):
# nationality           17588 non-null object
# club                  17588 non-null object
# club_position         17588 non-null object
# rating                17588 non-null int64
# height                17588 non-null object
# weight                17588 non-null object
# preffered_foot        17588 non-null object
# birth_date            17588 non-null object
# age                   17588 non-null int64
# preffered_position    17588 non-null object
# work_rate             17588 non-null object
# weak_foot             17588 non-null int64
# skill_moves           17588 non-null int64
# ball_control          17588 non-null int64
# dribbling             17588 non-null int64
# marking               17588 non-null int64
# sliding_tackle        17588 non-null int64
# standing_tackle       17588 non-null int64
# aggression            17588 non-null int64
# reactions             17588 non-null int64
# attacking_position    17588 non-null int64
# interceptions         17588 non-null int64
# vision                17588 non-null int64
# composure             17588 non-null int64
# crossing              17588 non-null int64
# short_pass            17588 non-null int64
# long_pass             17588 non-null int64
# acceleration          17588 non-null int64
# speed                 17588 non-null int64
# stamina               17588 non-null int64
# strength              17588 non-null int64
# balance               17588 non-null int64
# agility               17588 non-null int64
# jumping               17588 non-null int64
# heading               17588 non-null int64
# shot_power            17588 non-null int64
# finishing             17588 non-null int64
# long_shots            17588 non-null int64
# curve                 17588 non-null int64
# freekick_accuracy     17588 non-null int64
# penalties             17588 non-null int64
# volleys               17588 non-null int64
# dtypes: int64(33), object(9)
# memory usage: 6.4+ MB

# %% [markdown]
# ### 3. Who is the tallest French lefted foot player?

# %% [markdown]
# ### 4. Show a pandas series of every attribute's correlation with the rating attribute

# %% [markdown]
# ### 5. Make a heatmap of the dataset's correlation table

# %% [markdown]
# ### 6. Return a dataframe with only players from the following clubs. Call the dataframe fifa2. From now on we'll be using fifa2

# %%
clubs_list = ['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
              'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
              'Bor. Dortmund', 'Liverpool', 'Roma']

# %% [markdown]
# ### 7. Make a bar plot of the average long_shots, curve, and dribbling attributes of the clubs in the data

# %% [markdown]
# ### 8. Make a scatter plot of short_pass vs marking and use the preffered_foot column to color-encode the dots.

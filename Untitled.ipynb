# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
primary = pd.read_csv('primary_results.csv')

# %%
primary.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
county = pd.read_csv('county_facts.csv')

# %%
county.head()
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214    ...      SBO415207  \
# 0  308745538        6.2       23.1       14.5    ...            8.3
# 1    4779736        6.1       22.8       15.3    ...            1.2
# 2      54571        6.0       25.2       13.8    ...            0.7
# 3     182265        5.6       22.2       18.7    ...            1.3
# 4      27457        5.7       21.2       16.5    ...            0.0
#
#    SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# ...

# %%
county.info
# Out:
# <bound method DataFrame.info of        fips           area_name state_abbreviation  PST045214  PST040210  \
# 0         0       United States                NaN  318857056  308758105
# 1      1000             Alabama                NaN    4849377    4780127
# 2      1001      Autauga County                 AL      55395      54571
# 3      1003      Baldwin County                 AL     200111     182265
# 4      1005      Barbour County                 AL      26887      27457
# 5      1007         Bibb County                 AL      22506      22919
# 6      1009       Blount County                 AL      57719      57322
# 7      1011      Bullock County                 AL      10764      10915
# 8      1013       Butler County                 AL      20296      20946
# 9      1015      Calhoun County                 AL     115916     118586
# 10     1017     Chambers County                 AL      34076      34170
# ...

# %%
county_dict = pd.read_csv('county_facts_dictionary.csv')

# %%
county_dict.head()
# Out:
#   column_name                                        description
# 0   PST045214                          Population, 2014 estimate
# 1   PST040210          Population, 2010 (April 1) estimates base
# 2   PST120214  Population, percent change - April 1, 2010 to ...
# 3   POP010210                                   Population, 2010
# 4   AGE135214               Persons under 5 years, percent, 2014

# %%
df = pd.merge(primary, county, how='left', on='fips')

# %%
df.head()
# Out:
#      state state_abbreviation_x   county  fips     party        candidate  \
# 0  Alabama                   AL  Autauga  1001  Democrat   Bernie Sanders
# 1  Alabama                   AL  Autauga  1001  Democrat  Hillary Clinton
# 2  Alabama                   AL  Baldwin  1003  Democrat   Bernie Sanders
# 3  Alabama                   AL  Baldwin  1003  Democrat  Hillary Clinton
# 4  Alabama                   AL  Barbour  1005  Democrat   Bernie Sanders
#
#    votes  fraction_votes       area_name state_abbreviation_y    ...      \
# 0    544           0.182  Autauga County                   AL    ...
# 1   2387           0.800  Autauga County                   AL    ...
# 2   2694           0.329  Baldwin County                   AL    ...
# 3   5290           0.647  Baldwin County                   AL    ...
# 4    222           0.078  Barbour County                   AL    ...
#
#    SBO415207  SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  \
# ...

# %%
df.drop(labels='state_abbreviation_y', axis=1, inplace=True)

# %%
 df.head()
# Out:
#      state state_abbreviation_x   county  fips     party        candidate  \
# 0  Alabama                   AL  Autauga  1001  Democrat   Bernie Sanders
# 1  Alabama                   AL  Autauga  1001  Democrat  Hillary Clinton
# 2  Alabama                   AL  Baldwin  1003  Democrat   Bernie Sanders
# 3  Alabama                   AL  Baldwin  1003  Democrat  Hillary Clinton
# 4  Alabama                   AL  Barbour  1005  Democrat   Bernie Sanders
#
#    votes  fraction_votes       area_name  PST045214    ...      SBO415207  \
# 0    544           0.182  Autauga County    55395.0    ...            0.7
# 1   2387           0.800  Autauga County    55395.0    ...            0.7
# 2   2694           0.329  Baldwin County   200111.0    ...            1.3
# 3   5290           0.647  Baldwin County   200111.0    ...            1.3
# 4    222           0.078  Barbour County    26887.0    ...            0.0
#
#    SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  AFN120207  \
# ...

# %%
df.rename({'state_abbreviation_x': 'state_abbreviation'}, inplace=True)

# %%
pd.__version__
# Out:
# u'0.20.1'

# %%
county_dict.head()
# Out:
#   column_name                                        description
# 0   PST045214                          Population, 2014 estimate
# 1   PST040210          Population, 2010 (April 1) estimates base
# 2   PST120214  Population, percent change - April 1, 2010 to ...
# 3   POP010210                                   Population, 2010
# 4   AGE135214               Persons under 5 years, percent, 2014

# %%
county_dict.set_index('column_name',inplace=True)

# %%
county_dict.head()
# Out:
#                                                    description
# column_name
# PST045214                            Population, 2014 estimate
# PST040210            Population, 2010 (April 1) estimates base
# PST120214    Population, percent change - April 1, 2010 to ...
# POP010210                                     Population, 2010
# AGE135214                 Persons under 5 years, percent, 2014

# %%
county_dict.loc['MAN450207']
# Out:
# description    Manufacturers shipments, 2007 ($1,000)
# Name: MAN450207, dtype: object

# %%
df.isnull().sum()
# Out:
# state                      0
# state_abbreviation_x       0
# county                     0
# fips                     100
# party                      0
# candidate                  0
# votes                      0
# fraction_votes             0
# area_name               7132
# PST045214               7132
# PST040210               7132
# PST120214               7132
# POP010210               7132
# AGE135214               7132
# AGE295214               7132
# AGE775214               7132
# SEX255214               7132
# RHI125214               7132
# RHI225214               7132
# RHI325214               7132
# RHI425214               7132
# RHI525214               7132
# RHI625214               7132
# RHI725214               7132
# RHI825214               7132
# POP715213               7132
# POP645213               7132
# POP815213               7132
# EDU635213               7132
# EDU685213               7132
# VET605213               7132
# LFE305213               7132
# ...

# %%
df.dropna(axis=0, how='any', subset=['fips'], inplace=True)

# %%
df[df['fips'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [state, state_abbreviation_x, county, fips, party, candidate, votes, fraction_votes, area_name, PST045214, PST040210, PST120214, POP010210, AGE135214, AGE295214, AGE775214, SEX255214, RHI125214, RHI225214, RHI325214, RHI425214, RHI525214, RHI625214, RHI725214, RHI825214, POP715213, POP645213, POP815213, EDU635213, EDU685213, VET605213, LFE305213, HSG010214, HSG445213, HSG096213, HSG495213, HSD410213, HSD310213, INC910213, INC110213, PVY020213, BZA010213, BZA110213, BZA115213, NES010213, SBO001207, SBO315207, SBO115207, SBO215207, SBO515207, SBO415207, SBO015207, MAN450207, WTN220207, RTN130207, RTN131207, AFN120207, BPS030214, LND110210, POP060210]
# Index: []
#
# [0 rows x 60 columns]

# %%
df.head(10)
# Out:
#      state state_abbreviation_x   county  fips     party        candidate  \
# 0  Alabama                   AL  Autauga  1001  Democrat   Bernie Sanders
# 1  Alabama                   AL  Autauga  1001  Democrat  Hillary Clinton
# 2  Alabama                   AL  Baldwin  1003  Democrat   Bernie Sanders
# 3  Alabama                   AL  Baldwin  1003  Democrat  Hillary Clinton
# 4  Alabama                   AL  Barbour  1005  Democrat   Bernie Sanders
# 5  Alabama                   AL  Barbour  1005  Democrat  Hillary Clinton
# 6  Alabama                   AL     Bibb  1007  Democrat   Bernie Sanders
# 7  Alabama                   AL     Bibb  1007  Democrat  Hillary Clinton
# 8  Alabama                   AL   Blount  1009  Democrat   Bernie Sanders
# 9  Alabama                   AL   Blount  1009  Democrat  Hillary Clinton
#
#    votes  fraction_votes       area_name  PST045214    ...      SBO415207  \
# 0    544           0.182  Autauga County    55395.0    ...            0.7
# ...

# %%
county_pop_votes=df.groupby('county').agg({'votes' :'sum','PST045214':'max'}).dropna()

# %%
county_pop_votes.head()
# Out:
#            votes  PST045214
# county
# Abbeville   5480    24965.0
# Acadia      6629    62486.0
# Accomack    6750    33021.0
# Ada        57726   426236.0
# Adair      12570    25602.0

# %%
percentage=(county_pop_votes.votes/county_pop_votes.PST045214)*100

# %%
percentage.head()
# Out:
# county
# Abbeville    21.950731
# Acadia       10.608776
# Accomack     20.441537
# Ada          13.543201
# Adair        49.097727
# dtype: float64

# %%
percentage2=pd.DataFrame(percentage)
percentage2.head()
# Out:
#                    0
# county
# Abbeville  21.950731
# Acadia     10.608776
# Accomack   20.441537
# Ada        13.543201
# Adair      49.097727

# %%
percentage3 = percentage2.value >= 100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-2450a8213e7a> in <module>()
# ----> 1 percentage3 = percentage2.value >= 100
#
# /Users/jesun/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value'

# %%
percentage2.head()
# Out:
#                    0
# county
# Abbeville  21.950731
# Acadia     10.608776
# Accomack   20.441537
# Ada        13.543201
# Adair      49.097727

# %%
plt.boxplot(df.average_monthly_hours)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-587762b71aef> in <module>()
# ----> 1 plt.plot(flot.percentage2)
#
# NameError: name 'flot' is not defined
